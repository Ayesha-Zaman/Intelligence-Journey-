# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Zaman/Intelligence-Journey-/blob/main/OOP%20in%20Python/%20Inheritance%20%26%20Polymorphism/%20Topic_9_OOP(part_3)(Inheritance_%26_Polymorphism).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship)

# %%
# In aggregation one class owns the other class.
# For example there is one customer class and another is address class. There would be has-a relationship.
# like, customer has an address. customer owns address.
# we can't access private attribute while performing aggregation.

# %%
# code
class Customer:
  def __init__(self, name, gender, address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(), self.address.pin, self.address.state)

  def edit_profile(self,new_name, new_city, new_pin, new_state):
    self.name = new_name
    self.address.edit_address(new_city, new_pin, new_state)


class Address:
  def __init__(self, city, pin,state):
    self.__city = city
    self.pin = pin
    self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self, new_city, new_pin, new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state

add = Address('Gujrat', 595052, 'Punjab')

cust = Customer('Ayesha', 'female', add)
cust.print_address()

cust.edit_profile('sadia', 'sakardo', 349236, 'Gilgitbaltistaan')
cust.print_address()
# Out:
# Gujrat 595052 Punjab
# sakardo 349236 Gilgitbaltistaan

# %% [markdown]
# ##### Aggregation class diagram

# %% [markdown]
# ![Screenshot (92).png](data:image/png;base64,...)

# %% [markdown]
# ### Inheritance
#
# - What is inheritance
# - Example
# - What gets inherited?

# %% [markdown]
# ![Screenshot (94).png](data:image/png;base64,...)

# %%
# Inheritance and it's benefits
# awsome benefit is code readability + code reduction

# %%
# Example
# parent
class User:
  def __init__(self):
    self.name = 'ayesha'

  def login(self):
    print('login')

# child   --> can also access the attributes of parent class
class Student(User):

  # when child class do not have constructor, it will look for it in parent class and then will execute the piece of code in the
  # constructor of parent class will be excuted.

  def enroll(self):
    print('enroll in to the course.')

u = User()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# ayesha
# login
# enroll in to the course.

# %%
# Class diagram

# %% [markdown]
# ![Screenshot (95).png](data:image/png;base64,...)

# %% [markdown]
# ##### What gets inherited?
#
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2

# when child class have it's own constructor then parent class constructor would never be called.
# if parent class constructor wouldn't be called then variables inside that constructor wouldn't get initialized

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
# Out:
# Inside SmartPhone constructor

# %%
s.brand

# would be error bcz parent constructor wouldn't get executed.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-477493116.py in <cell line: 0>()
# ----> 1 s.brand
#       2
#       3 # would be error bcz parent constructor wouldn't get executed.
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
s.check()
# Out:
# Inside phone constructor
# Apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-25066133.py in <cell line: 0>()
#      18 s=SmartPhone(20000, "Apple", 13)
#      19 print(s.brand)
# ---> 20 s.check()
#
# /tmp/ipython-input-25066133.py in check(self)
#      14 class SmartPhone(Phone):
#      15     def check(self):
# ---> 16         print(self.__price)
#      17
#      18 s=SmartPhone(20000, "Apple", 13)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
# child can't access private methods of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def __show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
s.__show()
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-868419810.py in <cell line: 0>()
#      17
#      18 s=SmartPhone(20000, "Apple", 13)
# ---> 19 s.__show()
#
# AttributeError: 'SmartPhone' object has no attribute '__show'

# %%
# through getter method we can see private members

class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")

son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
# error bcz parent constructor never get executed

class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val

son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2052474890.py in <cell line: 0>()
#      18
#      19 son=Child(100,10)
# ---> 20 print("Parent: Num:",son.get_num())
#      21 print("Child: Val:",son.get_val())
#
# /tmp/ipython-input-2052474890.py in get_num(self)
#       7
#       8     def get_num(self):
# ----> 9         return self.__num
#      10
#      11 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):

    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %%
# Method Overriding
# if parent class and child class have same methods then child class method will be executed this is called method overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent's buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# using super outside the class       --> generate error bcz super() keyword can only be used in child class.
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method


s=SmartPhone(20000, "Apple", 13)

s.super().buy()
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1506172663.py in <cell line: 0>()
#      18 s=SmartPhone(20000, "Apple", 13)
#      19
# ---> 20 s.super().buy()
#
# AttributeError: 'SmartPhone' object has no attribute 'super'

# %%
# can super access parent's data?
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent's buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2097047998.py in <cell line: 0>()
#      19 s=SmartPhone(20000, "Apple", 13)
#      20
# ---> 21 s.buy()
#
# /tmp/ipython-input-2097047998.py in buy(self)
#      15         print ("Buying a smartphone")
#      16         # syntax to call parent's buy method
# ---> 17         print(super().brand)
#      18
#      19 s=SmartPhone(20000, "Apple", 13)
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):

    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val

son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200

    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Product, Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Product buy method

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):

    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):

    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-1644537074.py in <cell line: 0>()
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# /tmp/ipython-input-1644537074.py in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-1644537074.py in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
# Method overloading is having same name methods within same class serve same purpose but
# working mechanisim is different, it depends upon input.
# Method overloading doesn't work in python, bcz python only consider the latest method
class Shape:

  def area(self,radius):
    return 3.14*radius*radius
  def area(self, l, b):
    return l*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3551485256.py in <cell line: 0>()
#      11 s = Shape()
#      12
# ---> 13 print(s.area(2))
#      14 print(s.area(3,4))
#
# TypeError: Shape.area() missing 1 required positional argument: 'b'

# %%
# I't could be done through default agrguments
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %%
# Operator Overloading
# using single operator for different purposes like, + operator when input wil be different then purpose will be different

# %%
# concatination
'hello' + 'world'
# Out:
# 'helloworld'

# %%
# addition
4 + 5
# Out:
# 9

# %%
# merging
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Abstraction

# %%
# In abstraction, parent class impose certain rules or restrictions on child class.

# %%
# A class can only become abstract class if it inherit from 'ABC' and class must contain at least one
# abstract method
from abc import ABC,abstractmethod
class BankApp(ABC):

  def database(self):
    print('Connected to database.')

  @abstractmethod
  def security(self):
    pass


  @abstractmethod
  def display(self):
    pass

# %%
class MobileApp(BankApp):

  def mobile_login(self):
    print('login into mobile')

  def security(self):
    print('mobile security')

  def display(self):
    print('display')

# %%
mob = MobileApp()

# %%
mob.security()
# Out:
# mobile security

# %%
# error: bcz we can't create object of abstract class
obj = BankApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3880086753.py in <cell line: 0>()
#       1 # error: bcz we can't create object of abstract class
# ----> 2 obj = BankApp()
#
# TypeError: Can't instantiate abstract class BankApp without an implementation for abstract methods 'display', 'security'
