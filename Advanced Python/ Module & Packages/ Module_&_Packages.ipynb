# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Zaman/Intelligence-Journey-/blob/main/Advanced%20Python/%20Module%20%26%20Packages/%20Module_%26_Packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. What do you mean by __name__ == '__main__'

# %% [markdown]
# ### What is a module?
#
# Any file with an extention of .py is called a module in python.
#
# Whenever we execute a program it's module name is `__main__` and this name is stored in `__name__` variable

# %%
# File name would be '__main__' only for current executed file.
# If file is imported than name will not be main
# If a file like 'module1' is imported in another file like 'module2', then 'module1' name will be module1
# and the current executed file 'module2' name will be '__main__'

# %%
def display():
  print('hello')

display()
print(__name__)
# Out:
# hello
# __main__

# %% [markdown]
# ### Importing a module
#
# - But what is the need to import a module?
# - How to import a module

# %%
# Need of importing module:
#     -> code modularity, -> code reuse ability

# %%
# import a module
import test
test.hello('ayesha')
# Out:
# Hello! ayesha

# %%
# import multiple module -> user defined + builtin
import math
import test

test.hello('ayesha')
print(math.floor(4.3))
# Out:
# Hello! ayesha
# 4

# %% [markdown]
# ### Variations of import statement

# %%
# Normal
import math
import random

# %%
# clubbing together
import math,random,test

# %%
# importing specific names from module
from math import factorial,floor
from test import hello

print(factorial(5))
# Out:
# 120

# %%
# importing specific names from module
from math import factorial,floor
from test import hello

print(factorial(5))
ceil(4.8)   # Error: beacuse ceil is not imported
# Out:
# 120
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3926531463.py in <cell line: 0>()
#       4
#       5 print(factorial(5))
# ----> 6 ceil(4.8)   # Error: beacuse ceil is not imported
#
# NameError: name 'ceil' is not defined

# %%
# renaming modules
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


m.factorial(5)
# Out:
# 120

# %%
from math import factorial as f

f(5)
# Out:
# 120

# %% [markdown]
# ### Order of execution of a module

# %%
import sys
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ### What are packages in Python
#
# A package in python is a directory containing similar sub packages and modules.
#
# - A particular directory is treated as package if it has `__init__.py` file in it.
# - The `__init__.py` file may be empty or contain some initialization code related to the package

# %% [markdown]
# ### What are 3rd party packages?
#
# - The python community creates packages and make it available for other programmers
# - PyPI -> Python Package Index
# - You can upload your own package
# - You can also install packages from PyPI and install using pip
# - pip is a package manager utility
# - it is automatically installed with python
