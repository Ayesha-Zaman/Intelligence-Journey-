# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Zaman/Intelligence-Journey-/blob/main/07%3A%20Advanced%20Pandas/Topic%2022(2nd)%3A%20Vectorized%20DateTime%20in%20Pandas/Topic%2022(2nd)%3A%20Vectorized%20DateTime%20in%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Timestamp Object
#
# Time stamps refers particular moments in time (e.g., Oct 24th, 2022 at 7:00pm)

# %% [markdown]
# ### Creating Timestamp objects

# %%
# creating a timestamp
pd.Timestamp('2025/3/2')
# Out:
# Timestamp('2025-03-02 00:00:00')

# %%
# data type
type(pd.Timestamp('2025/3/2'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# variations
pd.Timestamp('2025-3-20')
pd.Timestamp('2025, 9, 3')
pd.Timestamp('2025, 9, 3')
# Out:
# Timestamp('2025-09-03 00:00:00')

# %%
# only year
pd.Timestamp('2026')
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
# using text
pd.Timestamp('25th feb 2026')
# Out:
# Timestamp('2026-02-25 00:00:00')

# %%
# providing time also
pd.Timestamp('25th feb 2026, 9:02PM')
# Out:
# Timestamp('2026-02-25 21:02:00')

# %%
# AM and PM
pd.Timestamp('25th feb 2026, 9:02AM')
# Out:
# Timestamp('2026-02-25 09:02:00')

# %%
# using datetime.datetime python's object
import datetime as dt

x = pd.Timestamp(dt.datetime(2026,4,3,9,34,53))
x
# Out:
# Timestamp('2026-04-03 09:34:53')

# %%
# fetching attributes
x.year
x.month
x.day
x.hour
x.minute
x.second
x.day_name()
x.month_name()
# Out:
# 'April'

# %%
# why separate objects to handle date and time when python already has datetime functionality?

# %% [markdown]
# - syntax wise datetime is very convenient
# - But the performance takes a hit while working with huge data. List vs Numpy Array
# - The weaknesses of Python's datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
# - The datetime64 dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2025-07-04', dtype=np.datetime64)
date
# Out:
# array('2025-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2025-07-04', '2025-07-05', '2025-07-06', '2025-07-07',
#        '2025-07-08', '2025-07-09', '2025-07-10', '2025-07-11',
#        '2025-07-12', '2025-07-13', '2025-07-14', '2025-07-15'],
#       dtype='datetime64[D]')

# %% [markdown]
# - Because of the uniform type in NumPy datetime64 arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python's datetime objects, especially as arrays get large
#
# - Pandas Timestamp object combines the ease-of-use of python datetime with the efficient storage and vectorized interface of numpy.datetime64
#
# - From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame

# %% [markdown]
# ### DatetimeIndex Object
#
# A collection of pandas timestamp

# %%
# from strings
type(pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1']))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# using python datetime object
pd.DatetimeIndex([dt.datetime(2023,1,1),dt.datetime(2022,1,1),dt.datetime(2021,1,1)])
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# using pd.timestamps
dt_index = pd.DatetimeIndex([pd.Timestamp(2023,1,1),pd.Timestamp(2022,1,1),pd.Timestamp(2021,1,1)])
dt_index
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# using datatimeindex as series index
pd.Series([1,2,3], index=dt_index)
# Out:
# 2023-01-01    1
# 2022-01-01    2
# 2021-01-01    3
# dtype: int64

# %% [markdown]
# ### date_range function

# %%
# generate daily dates in a given range
pd.date_range(start='2025/04/05', end='2025/07/05', freq='2D')
# Out:
# DatetimeIndex(['2025-04-05', '2025-04-07', '2025-04-09', '2025-04-11',
#                '2025-04-13', '2025-04-15', '2025-04-17', '2025-04-19',
#                '2025-04-21', '2025-04-23', '2025-04-25', '2025-04-27',
#                '2025-04-29', '2025-05-01', '2025-05-03', '2025-05-05',
#                '2025-05-07', '2025-05-09', '2025-05-11', '2025-05-13',
#                '2025-05-15', '2025-05-17', '2025-05-19', '2025-05-21',
#                '2025-05-23', '2025-05-25', '2025-05-27', '2025-05-29',
#                '2025-05-31', '2025-06-02', '2025-06-04', '2025-06-06',
#                '2025-06-08', '2025-06-10', '2025-06-12', '2025-06-14',
#                '2025-06-16', '2025-06-18', '2025-06-20', '2025-06-22',
#                '2025-06-24', '2025-06-26', '2025-06-28', '2025-06-30',
#                '2025-07-02', '2025-07-04'],
#               dtype='datetime64[ns]', freq='2D')

# %%
# alternate days in a given range
pd.date_range(start='2025/04/05', end='2025/07/05', freq='3D')
# Out:
# DatetimeIndex(['2025-04-05', '2025-04-08', '2025-04-11', '2025-04-14',
#                '2025-04-17', '2025-04-20', '2025-04-23', '2025-04-26',
#                '2025-04-29', '2025-05-02', '2025-05-05', '2025-05-08',
#                '2025-05-11', '2025-05-14', '2025-05-17', '2025-05-20',
#                '2025-05-23', '2025-05-26', '2025-05-29', '2025-06-01',
#                '2025-06-04', '2025-06-07', '2025-06-10', '2025-06-13',
#                '2025-06-16', '2025-06-19', '2025-06-22', '2025-06-25',
#                '2025-06-28', '2025-07-01', '2025-07-04'],
#               dtype='datetime64[ns]', freq='3D')

# %%
# B -> business days
pd.date_range(start='2025/1/5',end='2025/2/28',freq='B')
# Out:
# DatetimeIndex(['2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-13', '2025-01-14', '2025-01-15',
#                '2025-01-16', '2025-01-17', '2025-01-20', '2025-01-21',
#                '2025-01-22', '2025-01-23', '2025-01-24', '2025-01-27',
#                '2025-01-28', '2025-01-29', '2025-01-30', '2025-01-31',
#                '2025-02-03', '2025-02-04', '2025-02-05', '2025-02-06',
#                '2025-02-07', '2025-02-10', '2025-02-11', '2025-02-12',
#                '2025-02-13', '2025-02-14', '2025-02-17', '2025-02-18',
#                '2025-02-19', '2025-02-20', '2025-02-21', '2025-02-24',
#                '2025-02-25', '2025-02-26', '2025-02-27', '2025-02-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# W -> one day per week
pd.date_range(start='2023/1/5',end='2023/2/28',freq='W')
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday'],
#       dtype='object')

# %%
pd.date_range(start='2023/1/5',end='2023/2/28',freq='W-FRI')
# Out:
# DatetimeIndex(['2023-01-06', '2023-01-13', '2023-01-20', '2023-01-27',
#                '2023-02-03', '2023-02-10', '2023-02-17', '2023-02-24'],
#               dtype='datetime64[ns]', freq='W-FRI')

# %%
# h -> Hourly data(factor)
pd.date_range(start='2023/1/5',end='2023/2/28',freq='8h')
# Out:
# DatetimeIndex(['2023-01-05 00:00:00', '2023-01-05 08:00:00',
#                '2023-01-05 16:00:00', '2023-01-06 00:00:00',
#                '2023-01-06 08:00:00', '2023-01-06 16:00:00',
#                '2023-01-07 00:00:00', '2023-01-07 08:00:00',
#                '2023-01-07 16:00:00', '2023-01-08 00:00:00',
#                ...
#                '2023-02-25 00:00:00', '2023-02-25 08:00:00',
#                '2023-02-25 16:00:00', '2023-02-26 00:00:00',
#                '2023-02-26 08:00:00', '2023-02-26 16:00:00',
#                '2023-02-27 00:00:00', '2023-02-27 08:00:00',
#                '2023-02-27 16:00:00', '2023-02-28 00:00:00'],
#               dtype='datetime64[ns]', length=163, freq='8h')

# %%
# ME -> Month end
pd.date_range(start='2025/04/05',end='2025/07/05',freq='ME')
# Out:
# DatetimeIndex(['2025-04-30', '2025-05-31', '2025-06-30'], dtype='datetime64[ns]', freq='ME')

# %%
# MS -> Month start
pd.date_range(start='2025/04/05',end='2025/07/05',freq='MS')
# Out:
# DatetimeIndex(['2025-05-01', '2025-06-01', '2025-07-01'], dtype='datetime64[ns]', freq='MS')

# %%
# A -> Year end
pd.date_range(start='2025/04/05',end='2035/07/05',freq='YE')
# Out:
# DatetimeIndex(['2025-12-31', '2026-12-31', '2027-12-31', '2028-12-31',
#                '2029-12-31', '2030-12-31', '2031-12-31', '2032-12-31',
#                '2033-12-31', '2034-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
# using periods(number of results)
pd.date_range(start='2025/1/5',periods=25,freq='ME')
# Out:
# DatetimeIndex(['2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31',
#                '2026-01-31', '2026-02-28', '2026-03-31', '2026-04-30',
#                '2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31',
#                '2027-01-31'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# ### to_datetime function
#
# converts an existing objects to pandas timestamp/datetimeindex object

# %%
# simple series example

s = pd.Series(['2025/1/1','2024/5/1','2022/3/1'])
pd.to_datetime(s).dt.day_name()
# Out:
# 0    Wednesday
# 1    Wednesday
# 2      Tuesday
# dtype: object

# %%
pd.to_datetime(s).dt.month_name()
# Out:
# 0    January
# 1        May
# 2      March
# dtype: object

# %%
# with errors
s = pd.Series(['2023/1/1','2022/1/1','2021/130/1'])
pd.to_datetime(s,errors='coerce').dt.month_name()
# Out:
# 0    January
# 1    January
# 2        NaN
# dtype: object

# %%
df = pd.read_csv('/content/expense_data.csv')
df.shape
# Out:
# (277, 11)

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %% [markdown]
# ### dt accessor
#
# Accessor object for datetimelike properties of the Series values.

# %%
df['Date'].dt.is_quarter_start
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
# plot graph
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['INR'])

# %%
# day name wise bar chart/month wise bar chart

df['day_name'] = df['Date'].dt.day_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_name')['INR'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>
